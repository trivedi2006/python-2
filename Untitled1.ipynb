# %%
import pandas as pd
import numpy as np
df = pd.read_csv("train.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.duplicated(subset = ["Sex","Survived"]).sum()
# Out:
# 887

# %%
df.drop("Cabin",axis = 1)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.drop(df[(df["Sex"]=="male") & (df["Survived"]==1)].index)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.sort_values(["Age","Name"],ascending=[False,True])
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
# 851          852         0       3                   Svensson, Mr. Johan
# 493          494         0       1               Artagaveytia, Mr. Ramon
# 96            97         0       1             Goldschmidt, Mr. George B
# 116          117         0       3                  Connors, Mr. Patrick
# ..           ...       ...     ...                                   ...
# 55            56         1       1                     Woolner, Mr. Hugh
# 354          355         0       3                     Yousif, Mr. Wazli
# 495          496         0       3                 Yousseff, Mr. Gerious
# 240          241         0       3                 Zabour, Miss. Thamine
# 868          869         0       3           van Melkebeke, Mr. Philemon
#
#         Sex   Age  SibSp  Parch    Ticket     Fare Cabin Embarked
# ...

# %%
ds = df.set_index("Name")
ds
# Out:
#                                                     PassengerId  Survived  \
# Name
# Braund, Mr. Owen Harris                                       1         0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
# Heikkinen, Miss. Laina                                        3         1
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  4         1
# Allen, Mr. William Henry                                      5         0
# ...                                                         ...       ...
# Montvila, Rev. Juozas                                       887         0
# Graham, Miss. Margaret Edith                                888         1
# Johnston, Miss. Catherine Helen "Carrie"                    889         0
# Behr, Mr. Karl Howell                                       890         1
# Dooley, Mr. Patrick                                         891         0
#
# ...

# %%
ds.sort_index(axis = 0)
# Out:
#                                        PassengerId  Survived  Pclass     Sex  \
# Name
# Abbing, Mr. Anthony                            846         0       3    male
# Abbott, Mr. Rossmore Edward                    747         0       3    male
# Abbott, Mrs. Stanton (Rosa Hunt)               280         1       3  female
# Abelson, Mr. Samuel                            309         0       2    male
# Abelson, Mrs. Samuel (Hannah Wizosky)          875         1       2  female
# ...                                            ...       ...     ...     ...
# de Mulder, Mr. Theodore                        287         1       3    male
# de Pelsmaeker, Mr. Alfons                      283         0       3    male
# del Carlo, Mr. Sebastiano                      362         0       2    male
# van Billiard, Mr. Austin Blyler                154         0       3    male
# van Melkebeke, Mr. Philemon                    869         0       3    male
#
# ...

# %%
ds.sum(axis = 1)
# Out:
# Name
# Braund, Mr. Owen Harris                                 34.2500
# Cumings, Mrs. John Bradley (Florence Briggs Thayer)    114.2833
# Heikkinen, Miss. Laina                                  40.9250
# Futrelle, Mrs. Jacques Heath (Lily May Peel)            95.1000
# Allen, Mr. William Henry                                51.0500
#                                                          ...
# Montvila, Rev. Juozas                                  929.0000
# Graham, Miss. Margaret Edith                           939.0000
# Johnston, Miss. Catherine Helen "Carrie"               918.4500
# Behr, Mr. Karl Howell                                  948.0000
# Dooley, Mr. Patrick                                    933.7500
# Length: 891, dtype: float64

# %%
ds.corr()
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Age          0.096067
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000

# %%
pd.plotting.scatter_matrix(ds,figsize = (20,20))
# Out:
# array([[<AxesSubplot:xlabel='PassengerId', ylabel='PassengerId'>,
#         <AxesSubplot:xlabel='Survived', ylabel='PassengerId'>,
#         <AxesSubplot:xlabel='Pclass', ylabel='PassengerId'>,
#         <AxesSubplot:xlabel='Age', ylabel='PassengerId'>,
#         <AxesSubplot:xlabel='SibSp', ylabel='PassengerId'>,
#         <AxesSubplot:xlabel='Parch', ylabel='PassengerId'>,
#         <AxesSubplot:xlabel='Fare', ylabel='PassengerId'>],
#        [<AxesSubplot:xlabel='PassengerId', ylabel='Survived'>,
#         <AxesSubplot:xlabel='Survived', ylabel='Survived'>,
#         <AxesSubplot:xlabel='Pclass', ylabel='Survived'>,
#         <AxesSubplot:xlabel='Age', ylabel='Survived'>,
#         <AxesSubplot:xlabel='SibSp', ylabel='Survived'>,
#         <AxesSubplot:xlabel='Parch', ylabel='Survived'>,
#         <AxesSubplot:xlabel='Fare', ylabel='Survived'>],
#        [<AxesSubplot:xlabel='PassengerId', ylabel='Pclass'>,
#         <AxesSubplot:xlabel='Survived', ylabel='Pclass'>,
# ...

# %%
pd.crosstab(df["Survived"],df["Sex"],margins = True)
# Out:
# Sex       female  male  All
# Survived
# 0             81   468  549
# 1            233   109  342
# All          314   577  891

# %%
pd.plotting.parallel_coordinates(df,"Sex",["Pclass","Survived","Parch"])
# Out:
# <AxesSubplot:>

# %%
au

# %%
df.index
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.shape
# Out:
# (891, 12)

# %%
df.size # no of rows * no of columns
# Out:
# 10692

# %%
df.values
# Out:
# array([[1, 0, 3, ..., 7.25, nan, 'S'],
#        [2, 1, 1, ..., 71.2833, 'C85', 'C'],
#        [3, 1, 3, ..., 7.925, nan, 'S'],
#        ...,
#        [889, 0, 3, ..., 23.45, nan, 'S'],
#        [890, 1, 1, ..., 30.0, 'C148', 'C'],
#        [891, 0, 3, ..., 7.75, nan, 'Q']], dtype=object)

# %%
df.ndim
# Out:
# 2

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.T # transfom karse row nw columns ma
# Out:
#                                  0    \
# PassengerId                        1
# Survived                           0
# Pclass                             3
# Name         Braund, Mr. Owen Harris
# Sex                             male
# Age                               22
# SibSp                              1
# Parch                              0
# Ticket                     A/5 21171
# Fare                            7.25
# Cabin                            NaN
# Embarked                           S
#
#                                                            1    \
# PassengerId                                                  2
# Survived                                                     1
# Pclass                                                       1
# Name         Cumings, Mrs. John Bradley (Florence Briggs Th...
# Sex                                                     female
# Age                                                         38
# ...

# %%
df["Pclass"]
# Out:
# 0      3
# 1      1
# 2      3
# 3      1
# 4      3
#       ..
# 886    2
# 887    1
# 888    3
# 889    1
# 890    3
# Name: Pclass, Length: 891, dtype: int64

# %%
df[["Pclass","Age"]]
# Out:
#      Pclass   Age
# 0         3  22.0
# 1         1  38.0
# 2         3  26.0
# 3         1  35.0
# 4         3  35.0
# ..      ...   ...
# 886       2  27.0
# 887       1  19.0
# 888       3   NaN
# 889       1  26.0
# 890       3  32.0
#
# [891 rows x 2 columns]

# %%
len(df[(df["Sex"]=="male")  & (df["Survived"]==1)])
# Out:
# 109

# %%
df.iloc[2,2]
# Out:
# 3

# %%
df.iloc[2]
# Out:
# PassengerId                         3
# Survived                            1
# Pclass                              3
# Name           Heikkinen, Miss. Laina
# Sex                            female
# Age                                26
# SibSp                               0
# Parch                               0
# Ticket               STON/O2. 3101282
# Fare                            7.925
# Cabin                             NaN
# Embarked                            S
# Name: 2, dtype: object

# %%
df.iloc[:10,3:9]
# Out:
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
# 7                     Palsson, Master. Gosta Leonard    male   2.0      3
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
#
#    Parch            Ticket
# 0      0         A/5 21171
# 1      0          PC 17599
# 2      0  STON/O2. 3101282
# 3      0            113803
# ...

# %%
df1 = pd.DataFrame({"Sub":["python","FSD","COA","TOC","DM"],"FAC":["vha","psp","vby","dps","mss"],"mark":[10,9,10,9,9]})
df1
# Out:
#       Sub  FAC  mark
# 0  python  vha    10
# 1     FSD  psp     9
# 2     COA  vby    10
# 3     TOC  dps     9
# 4      DM  mss     9

# %%
df1 = df1.set_index("Sub",drop = True)
df1
# Out:
#         FAC  mark
# Sub
# python  vha    10
# FSD     psp     9
# COA     vby    10
# TOC     dps     9
# DM      mss     9

# %%
df = df.set_index("Name",drop = True)
df
# Out:
#                                                     PassengerId  Survived  \
# Name
# Braund, Mr. Owen Harris                                       1         0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
# Heikkinen, Miss. Laina                                        3         1
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  4         1
# Allen, Mr. William Henry                                      5         0
# ...                                                         ...       ...
# Montvila, Rev. Juozas                                       887         0
# Graham, Miss. Margaret Edith                                888         1
# Johnston, Miss. Catherine Helen "Carrie"                    889         0
# Behr, Mr. Karl Howell                                       890         1
# Dooley, Mr. Patrick                                         891         0
#
# ...

# %%
df = df.reset_index()

# %%
df
# Out:
#                                                   Name  PassengerId  Survived  \
# 0                              Braund, Mr. Owen Harris            1         0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...            2         1
# 2                               Heikkinen, Miss. Laina            3         1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)            4         1
# 4                             Allen, Mr. William Henry            5         0
# ..                                                 ...          ...       ...
# 886                              Montvila, Rev. Juozas          887         0
# 887                       Graham, Miss. Margaret Edith          888         1
# 888           Johnston, Miss. Catherine Helen "Carrie"          889         0
# 889                              Behr, Mr. Karl Howell          890         1
# 890                                Dooley, Mr. Patrick          891         0
#
# ...

# %%
df.loc["Montvila, Rev. Juozas"]
# Out:
# PassengerId       887
# Survived            0
# Pclass              2
# Sex              male
# Age                27
# SibSp               0
# Parch               0
# Ticket         211536
# Fare               13
# Cabin             NaN
# Embarked            S
# Name: Montvila, Rev. Juozas, dtype: object

# %%
df1.loc["FSD","FAC"] = "NAS"
df1
# Out:
#         FAC  mark
# Sub
# python  vha    10
# FSD     NAS     9
# COA     vby    10
# TOC     dps     9
# DM      mss     9

# %%
df1.loc["FSD","mark"] = 10
df1
# Out:
#         FAC  mark
# Sub
# python  vha    10
# FSD     NAS    10
# COA     vby    10
# TOC     dps     9
# DM      mss     9

# %%
df1.loc["project"] = ["vha",10]
df1
# Out:
#          FAC  mark
# Sub
# python   vha    10
# FSD      NAS    10
# COA      vby    10
# TOC      dps     9
# DM       mss     9
# project  vha    10

# %%
df1["new"] = df1["mark"]*10
df1
# Out:
#          FAC  mark  new
# Sub
# python   vha    10  100
# FSD      NAS    10  100
# COA      vby    10  100
# TOC      dps     9   90
# DM       mss     9   90
# project  vha    10  100

# %%
df["child"] = df["Parch"]+df["SibSp"]
df
# Out:
#                                                     PassengerId  Survived  \
# Name
# Braund, Mr. Owen Harris                                       1         0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
# Heikkinen, Miss. Laina                                        3         1
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  4         1
# Allen, Mr. William Henry                                      5         0
# ...                                                         ...       ...
# Montvila, Rev. Juozas                                       887         0
# Graham, Miss. Margaret Edith                                888         1
# Johnston, Miss. Catherine Helen "Carrie"                    889         0
# Behr, Mr. Karl Howell                                       890         1
# Dooley, Mr. Patrick                                         891         0
#
# ...

# %%
from numpy import random
n = np.array(np.random.randint(1,100,(8,5)))

ds3 = pd.DataFrame(n,columns=["A","B","C","D","E"])
ds3.shape
# Out:
# [[71 99 93 84 49]
#  [90 46 75  8 58]
#  [77 20 87 77 83]
#  [53 80 73 56 96]
#  [51 11 47 18 30]
#  [96 60 35 40 30]
#  [25 84 45  1 17]
#  [46 15 42 52 16]]
# (8, 5)

# %%
ds3.size
# Out:
# 40

# %%
ds3.ndim
# Out:
# 2

# %%
ds3["Sum"] = ds3["A"]+ds3["B"]+ds3["C"]+ds3["D"]+ds3["E"]
ds3
# Out:
#     A   B   C   D   E  Sum
# 0  71  99  93  84  49  396
# 1  90  46  75   8  58  277
# 2  77  20  87  77  83  344
# 3  53  80  73  56  96  358
# 4  51  11  47  18  30  157
# 5  96  60  35  40  30  261
# 6  25  84  45   1  17  172
# 7  46  15  42  52  16  171

# %%
ds3.iloc[6,2] = 54
ds3
# Out:
#     A   B   C   D   E  Sum
# 0  71  99  93  84  49  396
# 1  90  46  75   8  58  277
# 2  77  20  87  77  83  344
# 3  53  80  73  56  96  358
# 4  51  11  47  18  30  157
# 5  96  60  35  40  30  261
# 6  25  84  54   1  17  172
# 7  46  15  42  52  16  171

# %%
ds3.iloc[2:8,1:4]
ds3
# Out:
#     A   B   C   D   E  Sum
# 0  71  99  93  84  49  396
# 1  90  46  75   8  58  277
# 2  77  20  87  77  83  344
# 3  53  80  73  56  96  358
# 4  51  11  47  18  30  157
# 5  96  60  35  40  30  261
# 6  25  84  54   1  17  172
# 7  46  15  42  52  16  171

# %%
ds3.loc[8] = [50,60,70,80,52,158]
ds3
# Out:
#     A   B   C   D   E  Sum
# 0  71  99  93  84  49  396
# 1  90  46  75   8  58  277
# 2  77  20  87  77  83  344
# 3  53  80  73  56  96  358
# 4  51  11  47  18  30  157
# 5  96  60  35  40  30  261
# 6  25  84  54   1  17  172
# 7  46  15  42  52  16  171
# 8  50  60  70  80  52  158

# %%
df.head()
# Out:
#                                                     PassengerId  Survived  \
# Name
# Braund, Mr. Owen Harris                                       1         0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
# Heikkinen, Miss. Laina                                        3         1
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  4         1
# Allen, Mr. William Henry                                      5         0
#
#                                                     Pclass     Sex   Age  \
# Name
# Braund, Mr. Owen Harris                                  3    male  22.0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...       1  female  38.0
# Heikkinen, Miss. Laina                                   3  female  26.0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)             1  female  35.0
# Allen, Mr. William Henry                                 3    male  35.0
#
#                                                     SibSp  Parch  \
# ...

# %%
df.sample(7)
# Out:
#                                                     PassengerId  Survived  \
# Name
# Turpin, Mrs. William John Robert (Dorothy Ann W...           42         0
# Natsch, Mr. Charles H                                       274         0
# Yasbeck, Mr. Antoni                                         621         0
# Jussila, Mr. Eiriik                                         580         1
# Moss, Mr. Albert Johan                                      108         1
# Lefebre, Miss. Jeannie                                      486         0
# Coxon, Mr. Daniel                                            95         0
#
#                                                     Pclass     Sex   Age  \
# Name
# Turpin, Mrs. William John Robert (Dorothy Ann W...       2  female  27.0
# Natsch, Mr. Charles H                                    1    male  37.0
# Yasbeck, Mr. Antoni                                      3    male  27.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 891 entries, Braund, Mr. Owen Harris to Dooley, Mr. Patrick
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Sex          891 non-null    object
#  4   Age          714 non-null    float64
#  5   SibSp        891 non-null    int64
#  6   Parch        891 non-null    int64
#  7   Ticket       891 non-null    object
#  8   Fare         891 non-null    float64
#  9   Cabin        204 non-null    object
#  10  Embarked     889 non-null    object
#  11  child        891 non-null    int64
# dtypes: float64(2), int64(6), object(4)
# memory usage: 130.5+ KB

# %%
df.describe(include = "object")
# Out:
#          Sex Ticket Cabin Embarked
# count    891    891   204      889
# unique     2    681   147        3
# top     male   1601    G6        S
# freq     577      7     4      644

# %%
df.describe(exclude = "int")
# Out:
#         PassengerId    Survived      Pclass                   Name   Sex  \
# count    891.000000  891.000000  891.000000                    891   891
# unique          NaN         NaN         NaN                    891     2
# top             NaN         NaN         NaN  Maioni, Miss. Roberta  male
# freq            NaN         NaN         NaN                      1   577
# mean     446.000000    0.383838    2.308642                    NaN   NaN
# std      257.353842    0.486592    0.836071                    NaN   NaN
# min        1.000000    0.000000    1.000000                    NaN   NaN
# 25%      223.500000    0.000000    2.000000                    NaN   NaN
# 50%      446.000000    0.000000    3.000000                    NaN   NaN
# 75%      668.500000    1.000000    3.000000                    NaN   NaN
# max      891.000000    1.000000    3.000000                    NaN   NaN
#
#                Age       SibSp       Parch Ticket        Fare    Cabin  \
# ...

# %%
df1=pd.DataFrame([[1,np.nan,3,4],[2,3,np.nan,8],[np.nan,4,5,9],[np.nan,1,np.nan,3],[np.nan,np.nan,np.nan,np.nan]],columns=["A","B","C","D"])
df1
# Out:
#      A    B    C    D
# 0  1.0  NaN  3.0  4.0
# 1  2.0  3.0  NaN  8.0
# 2  NaN  4.0  5.0  9.0
# 3  NaN  1.0  NaN  3.0
# 4  NaN  NaN  NaN  NaN

# %%
df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.dropna()
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df1.dropna()
# Out:
# Empty DataFrame
# Columns: [A, B, C, D]
# Index: []

# %%
df1.dropna(subset = ["B","D"],how = "all")
# Out:
#      A    B    C    D
# 0  1.0  NaN  3.0  4.0
# 1  2.0  3.0  NaN  8.0
# 2  NaN  4.0  5.0  9.0
# 3  NaN  1.0  NaN  3.0

# %%
df.dropna(subset = ["Cabin"])
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df1.fillna(df.mean())
# Out:
#      A    B    C    D
# 0  1.0  NaN  3.0  4.0
# 1  2.0  3.0  NaN  8.0
# 2  NaN  4.0  5.0  9.0
# 3  NaN  1.0  NaN  3.0
# 4  NaN  NaN  NaN  NaN

# %%
df["Age"] = df["Age"].fillna(df["Age"].mean())
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %%
df.nunique()
# Out:
# PassengerId    891
# Survived         2
# Pclass           3
# Name           891
# Sex              2
# Age             89
# SibSp            7
# Parch            7
# Ticket         681
# Fare           248
# Cabin          147
# Embarked         3
# dtype: int64

# %%
df.Sex.unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
df.Sex.value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
df.Embarked.mode()[0]
# Out:
# 'S'
