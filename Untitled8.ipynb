# %%
import pandas as pd
import numpy as np 
import plotly.express as px
import plotly.io as pio
pio.renderers.default="notebook"

# %%
df = pd.read_csv("social_media_engagement.csv")

# %%
df.nunique()
# Out:
# post_id            100
# platform             3
# post_type            5
# post_time           99
# likes               93
# comments            85
# shares              96
# post_day             7
# sentiment_score      3
# dtype: int64

# %%
px.bar(x=df.post_type,y = df.likes,width=1000,height=1000,title="post_type vs likes",text_auto=True,color=df.platform,color_discrete_map = {"Facebook":"blue","Instagram":"pink","Twitter":"black"})
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\plotly\io\_renderers.py:51: UserWarning: Plotly version >= 6 requires Jupyter Notebook >= 7 but you have 6.1.4 installed.
#  To upgrade Jupyter Notebook, please run `pip install notebook --upgrade`.
#   warnings.warn(
# ...

# %%
px.bar(x=df.post_type,y = df.likes,width=1000,height=1000,title="post_type vs likes",text_auto=True,color=df.platform,color_discrete_sequence = ["blue","pink","black"])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\plotly\io\_renderers.py:51: UserWarning: Plotly version >= 6 requires Jupyter Notebook >= 7 but you have 6.1.4 installed.
#  To upgrade Jupyter Notebook, please run `pip install notebook --upgrade`.
#   warnings.warn(
# ...

# %%
px.bar(x=df.post_type,y = df.likes,width=1000,height=1000,title="post_type vs likes",text_auto=True,color=df.comments)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\plotly\io\_renderers.py:51: UserWarning: Plotly version >= 6 requires Jupyter Notebook >= 7 but you have 6.1.4 installed.
#  To upgrade Jupyter Notebook, please run `pip install notebook --upgrade`.
#   warnings.warn(
# ...

# %%
px.bar(x=df.post_type,y = df.likes,width=1000,height=1000,title="post_type vs likes",text_auto=True,color=df.comments,hover_data = [df.post_day,df.sentiment_score])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\plotly\io\_renderers.py:51: UserWarning: Plotly version >= 6 requires Jupyter Notebook >= 7 but you have 6.1.4 installed.
#  To upgrade Jupyter Notebook, please run `pip install notebook --upgrade`.
#   warnings.warn(
# ...

# %%
px.bar(x=df.post_type,y = df.likes,width=1000,height=1000,title="post_type vs likes",text_auto=True,color=df.comments,orientation="v")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\plotly\io\_renderers.py:51: UserWarning: Plotly version >= 6 requires Jupyter Notebook >= 7 but you have 6.1.4 installed.
#  To upgrade Jupyter Notebook, please run `pip install notebook --upgrade`.
#   warnings.warn(
# ...

# %%
px.bar(y=df.post_type,x = df.likes,width=1000,height=1000,title="post_type vs likes",text_auto=True,color=df.comments,orientation="h")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\plotly\io\_renderers.py:51: UserWarning: Plotly version >= 6 requires Jupyter Notebook >= 7 but you have 6.1.4 installed.
#  To upgrade Jupyter Notebook, please run `pip install notebook --upgrade`.
#   warnings.warn(
# ...

# %%
px.bar(x=df.post_type,y = df.likes,width=1000,height=1000,title="post_type vs likes",text=df.likes,color=df.comments,orientation="v")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\plotly\io\_renderers.py:51: UserWarning: Plotly version >= 6 requires Jupyter Notebook >= 7 but you have 6.1.4 installed.
#  To upgrade Jupyter Notebook, please run `pip install notebook --upgrade`.
#   warnings.warn(
# ...

# %%
px.bar(x=df.post_type,y = [df.likes,df.comments,df.shares],width=1000,height=1000,title="post_type vs likes",text=df.likes,color=df.platform,hover_data = [df.post_day,df.sentiment_score],pattern_shape = df.sentiment_score)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\plotly\io\_renderers.py:51: UserWarning: Plotly version >= 6 requires Jupyter Notebook >= 7 but you have 6.1.4 installed.
#  To upgrade Jupyter Notebook, please run `pip install notebook --upgrade`.
#   warnings.warn(
# ...

# %%
px.bar(x=df.post_type,y = df.likes,width=1000,height=1000,title="post_type vs likes",text_auto=True,color=df.comments,hover_data = [df.post_day,df.sentiment_score])

# %%
px.bar(x = df.post_type,y = [df.likes,df.comments,df.shares],barmode="stack")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\plotly\io\_renderers.py:51: UserWarning: Plotly version >= 6 requires Jupyter Notebook >= 7 but you have 6.1.4 installed.
#  To upgrade Jupyter Notebook, please run `pip install notebook --upgrade`.
#   warnings.warn(
# ...

# %%
px.bar(x = df.post_type,y = [df.likes,df.comments,df.shares],barmode="group")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\plotly\io\_renderers.py:51: UserWarning: Plotly version >= 6 requires Jupyter Notebook >= 7 but you have 6.1.4 installed.
#  To upgrade Jupyter Notebook, please run `pip install notebook --upgrade`.
#   warnings.warn(
# ...

# %%
px.bar(x = df.post_type,y = [df.likes,df.comments,df.shares],barmode="stack")

# %%
df["comments_n"] = df["comments"]*-1

# %%
px.bar(x = df.post_id,y = [df.comments_n,df.shares],barmode="relative")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\plotly\io\_renderers.py:51: UserWarning: Plotly version >= 6 requires Jupyter Notebook >= 7 but you have 6.1.4 installed.
#  To upgrade Jupyter Notebook, please run `pip install notebook --upgrade`.
#   warnings.warn(
# ...

# %%
data = pd.DataFrame({"c":["a","b","c"],"v":[10,-20,30]})
px.bar(x = data.c,y = data.v,barmode="relative")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\plotly\io\_renderers.py:51: UserWarning: Plotly version >= 6 requires Jupyter Notebook >= 7 but you have 6.1.4 installed.
#  To upgrade Jupyter Notebook, please run `pip install notebook --upgrade`.
#   warnings.warn(
# ...

# %%
px.scatter(x = df.comments,y = df.likes,title="comments vs likes",height=500,width=500,color = df.platform,symbol = df.platform)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\plotly\io\_renderers.py:51: UserWarning: Plotly version >= 6 requires Jupyter Notebook >= 7 but you have 6.1.4 installed.
#  To upgrade Jupyter Notebook, please run `pip install notebook --upgrade`.
#   warnings.warn(
# ...

# %%
px.scatter(x = df.comments,y = df.likes,size = df.shares) # bubble chart
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\plotly\io\_renderers.py:51: UserWarning: Plotly version >= 6 requires Jupyter Notebook >= 7 but you have 6.1.4 installed.
#  To upgrade Jupyter Notebook, please run `pip install notebook --upgrade`.
#   warnings.warn(
# ...

# %%
px.scatter(x = df.comments,y = df.likes,size = df.shares,color = df.post_type) # bubble chart
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\plotly\io\_renderers.py:51: UserWarning: Plotly version >= 6 requires Jupyter Notebook >= 7 but you have 6.1.4 installed.
#  To upgrade Jupyter Notebook, please run `pip install notebook --upgrade`.
#   warnings.warn(
# ...

# %%
px.scatter(x = df.comments,y = df.likes,size = df.shares,color = df.post_type,facet_row=df.post_day,facet_col = df.sentiment_score,height = 2000,width=2000)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\plotly\io\_renderers.py:51: UserWarning: Plotly version >= 6 requires Jupyter Notebook >= 7 but you have 6.1.4 installed.
#  To upgrade Jupyter Notebook, please run `pip install notebook --upgrade`.
#   warnings.warn(
# ...

# %%
px.scatter_3d(x = df.likes,y = df.comments,z = df.shares)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\plotly\io\_renderers.py:51: UserWarning: Plotly version >= 6 requires Jupyter Notebook >= 7 but you have 6.1.4 installed.
#  To upgrade Jupyter Notebook, please run `pip install notebook --upgrade`.
#   warnings.warn(
# ...

# %%
px.scatter_matrix(dimensions = [df.comments,df.shares,df.likes],color = df.platform,size = df.shares)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\plotly\io\_renderers.py:51: UserWarning: Plotly version >= 6 requires Jupyter Notebook >= 7 but you have 6.1.4 installed.
#  To upgrade Jupyter Notebook, please run `pip install notebook --upgrade`.
#   warnings.warn(
# ...

# %%
df1 = df.groupby("platform",as_index=False)[["likes","comments","shares"]].sum()
df1
# Out:
#     platform   likes  comments  shares
# 0   Facebook   86392      7965   15180
# 1  Instagram  107994      8368   18906
# 2    Twitter   43795      3933    7479

# %%
fig = px.pie(data_frame = df1,values="likes",names = "platform",color_discrete_sequence=["grey","lightgreen","pink"])
fig.update_traces(textinfo="percent+label",textposition="outside",pull=[0.2,0,0])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\plotly\io\_renderers.py:51: UserWarning: Plotly version >= 6 requires Jupyter Notebook >= 7 but you have 6.1.4 installed.
#  To upgrade Jupyter Notebook, please run `pip install notebook --upgrade`.
#   warnings.warn(
# ...

# %%
px.line(data_frame = df,x = "post_id",y = "likes",color = df.platform,markers=True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\plotly\io\_renderers.py:51: UserWarning: Plotly version >= 6 requires Jupyter Notebook >= 7 but you have 6.1.4 installed.
#  To upgrade Jupyter Notebook, please run `pip install notebook --upgrade`.
#   warnings.warn(
# ...

# %%
px.line(data_frame = df,x = "platform",y = "likes",color = df.platform,markers=True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\plotly\io\_renderers.py:51: UserWarning: Plotly version >= 6 requires Jupyter Notebook >= 7 but you have 6.1.4 installed.
#  To upgrade Jupyter Notebook, please run `pip install notebook --upgrade`.
#   warnings.warn(
# ...

# %%
pd.get_dummies(df)
# Out:
#     post_id  likes  comments  shares  comments_n  platform_Facebook  \
# 0         1   2121       474     628        -474               True
# 1         2   3660       432     694        -432               True
# 2         3   4955       408     688        -408              False
# 3         4   1183        90     187         -90              False
# 4         5   3499       247     286        -247              False
# ..      ...    ...       ...     ...         ...                ...
# 95       96     36       294     911        -294              False
# 96       97    314       108     458        -108              False
# 97       98    229       179      38        -179              False
# 98       99   5000       500     204        -500              False
# 99      100   4483       357      25        -357              False
#
#     platform_Instagram  platform_Twitter  post_type_carousel  post_type_image  \
# ...
